# %%
import pandas as pd

# %%
df = pd.read_parquet("oiseaux-france.parquet")
# Out:
# scientificName
# Lyrurus tetrix (Linnaeus, 1758)    5558
# Tetrao tetrix Linnaeus, 1758        492
# Name: count, dtype: int64

# %%
df.head(3)
# Out:
#   class            order            family          genus  \
# 0  Aves  Charadriiformes  Recurvirostridae  Recurvirostra
# 1  Aves  Charadriiformes           Laridae    Hydroprogne
# 2  Aves    Passeriformes        Certhiidae        Certhia
#
#                   species                         scientificName  \
# 0  Recurvirostra avosetta  Recurvirostra avosetta Linnaeus, 1758
# 1      Hydroprogne caspia      Hydroprogne caspia (Pallas, 1770)
# 2   Certhia brachydactyla  Certhia brachydactyla C.L.Brehm, 1820
#
#    decimalLatitude  decimalLongitude  coordinateUncertaintyInMeters  \
# 0         43.35635           4.81863                          250.0
# 1         43.35635           4.81863                          250.0
# 2         43.71169           5.07810                          250.0
#
#    elevation   eventDate  month  year  speciesKey        recordedBy
# 0        2.0  2020-09-30    9.0  2020   2480259.0  MéZENGE François
# 1        1.0  2020-09-08    9.0  2020   2481236.0      BLASCO André
# 2      112.0  2020-02-20    2.0  2020   7806848.0      FLITTI Amine

# %%
df["speciesKey"] = df["speciesKey"].astype("category")
df["species"].value_counts()
# Out:
# species
# Fringilla coelebs           233761
# Erithacus rubecula          216847
# Turdus merula               215123
# Parus major                 197240
# Sylvia atricapilla          175853
#                              ...
# Tyto furcata                     1
# Leucopternis schistaceus         1
# Spinus pinus                     1
# Loxia leucoptera                 1
# Spizella passerina               1
# Name: count, Length: 585, dtype: int64

# %%
mapping = pd.read_csv("taxref_species_vernacular_mapping.csv")

df = df.merge(mapping, on="species", how="left")

# %%
df.head()
# Out:
#   class            order            family          genus  \
# 0  Aves  Charadriiformes  Recurvirostridae  Recurvirostra
# 1  Aves  Charadriiformes           Laridae    Hydroprogne
# 2  Aves    Passeriformes        Certhiidae        Certhia
# 3  Aves    Passeriformes      Fringillidae      Carduelis
# 4  Aves    Passeriformes       Emberizidae       Emberiza
#
#                   species                         scientificName  \
# 0  Recurvirostra avosetta  Recurvirostra avosetta Linnaeus, 1758
# 1      Hydroprogne caspia      Hydroprogne caspia (Pallas, 1770)
# 2   Certhia brachydactyla  Certhia brachydactyla C.L.Brehm, 1820
# 3     Carduelis carduelis   Carduelis carduelis (Linnaeus, 1758)
# 4       Emberiza calandra       Emberiza calandra Linnaeus, 1758
#
#    decimalLatitude  decimalLongitude  coordinateUncertaintyInMeters  \
# 0         43.35635           4.81863                          250.0
# 1         43.35635           4.81863                          250.0
# 2         43.71169           5.07810                          250.0
# 3         43.06400           5.85255                          250.0
# 4         43.63410           6.37685                           25.0
#
#    elevation   eventDate  month  year speciesKey        recordedBy  \
# 0        2.0  2020-09-30    9.0  2020  2480259.0  MéZENGE François
# 1        1.0  2020-09-08    9.0  2020  2481236.0      BLASCO André
# 2      112.0  2020-02-20    2.0  2020  7806848.0      FLITTI Amine
# 3       24.0  2020-04-20    4.0  2020  2494686.0       ZWANK Aline
# 4      634.0  2020-10-24   10.0  2020  7634625.0    SPAETH Estelle
#
#         vernacularName_fr
# 0       Avocette élégante
# 1        Sterne caspienne
# 2  Grimpereau des jardins
# 3    Chardonneret élégant
# 4           Bruant proyer
